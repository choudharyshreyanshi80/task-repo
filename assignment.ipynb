# %%
name="Shreyanshi"
age=20

print("Name:",name,"Age:",age)
# Out:
# Name: Shreyanshi Age: 20

# %%
print("2026","06","09",sep="-")
# Out:
# 2026-06-09

# %%
print("Home","About","Contact",sep="|")
# Out:
# Home|About|Contact

# %%
print("Hello",end=" ")
print("World")
# Out:
# Hello World

# %%
print("Apple", "Banana", "Mango", sep=", ", end=".\n")
# Out:
# Apple, Banana, Mango.

# %%
name=input("Enter your name:")
print("Hello!! ",name)
# Out:
# Hello!!  shreyanshi
